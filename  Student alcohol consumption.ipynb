# %% [markdown]
# In this study, student alcohol consumption data is evaluated according to their student class, student school, sex, age and address

# %% [markdown]
# # Import the libraries

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Load the data

# %%
mat_data= pd.read_csv('student-mat.csv')
por_data= pd.read_csv('student-por.csv')

# %%
 student = pd.merge(por_data, mat_data, how='outer', on=["school","sex","age","address","famsize","Pstatus","Medu","Fedu","Mjob","Fjob","reason","nursery","internet","guardian","traveltime","studytime","famsup","activities","higher","romantic","famrel","freetime","goout","Dalc","Walc","health","schoolsup"])

# %%
student
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# 5       GP   M   16       U     LE3       T     4     3  services     other
# 6       GP   M   16       U     LE3       T     2     2     other     other
# 7       GP   F   17       U     GT3       A     4     4     other   teacher
# 8       GP   M   15       U     LE3       A     3     2  services     other
# 9       GP   M   15       U     GT3       T     3     4     other     other
# 10      GP   F   15       U     GT3       T     4     4   teacher    health
# 11      GP   F   15       U     GT3       T     2     1  services     other
# 12      GP   M   15       U     LE3       T     4     4    health  services
# 13      GP   M   15       U     GT3       T     4     3   teacher     other
# 14      GP   M   15       U     GT3       A     2     2     other     other
# 15      GP   F   16       U     GT3       T     4     4    health     other
# 16      GP   F   16       U     GT3       T     4     4  services  services
# 17      GP   F   16       U     GT3       T     3     3     other     other
# 18      GP   M   17       U     GT3       T     3     2  services  services
# 19      GP   M   16       U     LE3       T     4     3    health     other
# 20      GP   M   15       U     GT3       T     4     3   teacher     other
# 21      GP   M   15       U     GT3       T     4     4    health    health
# 22      GP   M   16       U     LE3       T     4     2   teacher     other
# 23      GP   M   16       U     LE3       T     2     2     other     other
# 24      GP   F   15       R     GT3       T     2     4  services    health
# 25      GP   F   16       U     GT3       T     2     2  services  services
# 26      GP   M   15       U     GT3       T     2     2     other     other
# 27      GP   M   15       U     GT3       T     4     2    health  services
# 28      GP   M   16       U     LE3       A     3     4  services     other
# 29      GP   M   16       U     GT3       T     4     4   teacher   teacher
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
# 649     GP   M   18       R     GT3       T     2     2  services     other
# 650     GP   M   15       R     GT3       T     3     2     other     other
# 651     GP   M   16       U     LE3       T     1     2     other     other
# 652     GP   M   17       U     GT3       T     1     3   at_home  services
# 653     GP   M   16       U     GT3       T     3     2  services  services
# 654     GP   F   18       U     LE3       T     2     1  services   at_home
# 655     GP   M   19       U     GT3       T     3     3     other     other
# 656     GP   F   18       U     GT3       T     2     4  services   at_home
# 657     GP   M   19       U     GT3       T     4     4   teacher  services
# 658     GP   F   19       U     LE3       T     1     1   at_home     other
# 659     GP   F   19       U     LE3       T     1     2  services  services
# 660     GP   F   19       U     GT3       T     2     1   at_home     other
# 661     GP   M   19       U     GT3       T     1     2     other  services
# 662     GP   F   19       U     LE3       T     3     2  services     other
# 663     GP   F   19       U     GT3       T     1     1   at_home    health
# 664     GP   F   19       R     GT3       T     2     3     other     other
# 665     GP   F   19       R     GT3       A     3     1  services   at_home
# 666     GP   F   19       U     GT3       T     2     1  services  services
# 667     MS   F   18       R     LE3       A     1     4   at_home     other
# 668     MS   M   18       R     LE3       T     1     1   at_home     other
# 669     MS   F   19       U     LE3       T     3     2  services  services
# 670     MS   F   20       U     GT3       T     4     2    health     other
# 671     MS   M   20       U     LE3       A     2     2  services  services
# 672     MS   M   21       R     GT3       T     1     1     other     other
# 673     MS   M   19       U     LE3       T     1     1     other   at_home
#
#      ...  absences_x  G1_x  G2_x  G3_x  failures_y paid_y absences_y  G1_y  \
# 0    ...         4.0   0.0  11.0  11.0         0.0     no        6.0   5.0
# 1    ...         2.0   9.0  11.0  11.0         0.0     no        4.0   5.0
# 2    ...         6.0  12.0  13.0  12.0         3.0    yes       10.0   7.0
# 3    ...         0.0  14.0  14.0  14.0         0.0    yes        2.0  15.0
# 4    ...         0.0  11.0  13.0  13.0         0.0    yes        4.0   6.0
# 5    ...         6.0  12.0  12.0  13.0         0.0    yes       10.0  15.0
# 6    ...         0.0  13.0  12.0  13.0         0.0     no        0.0  12.0
# 7    ...         2.0  10.0  13.0  13.0         0.0     no        6.0   6.0
# 8    ...         0.0  15.0  16.0  17.0         0.0    yes        0.0  16.0
# 9    ...         0.0  12.0  12.0  13.0         0.0    yes        0.0  14.0
# 10   ...         2.0  14.0  14.0  14.0         0.0    yes        0.0  10.0
# 11   ...         0.0  10.0  12.0  13.0         0.0     no        4.0  10.0
# 12   ...         0.0  12.0  13.0  12.0         0.0    yes        2.0  14.0
# 13   ...         0.0  12.0  12.0  13.0         0.0    yes        2.0  10.0
# 14   ...         0.0  14.0  14.0  15.0         0.0     no        0.0  14.0
# 15   ...         6.0  17.0  17.0  17.0         0.0     no        4.0  14.0
# 16   ...        10.0  13.0  13.0  14.0         0.0    yes        6.0  13.0
# 17   ...         2.0  13.0  14.0  14.0         0.0     no        4.0   8.0
# 18   ...         2.0   8.0   8.0   7.0         3.0     no       16.0   6.0
# 19   ...         6.0  12.0  12.0  12.0         0.0    yes        4.0   8.0
# 20   ...         0.0  12.0  13.0  14.0         0.0     no        0.0  13.0
# 21   ...         0.0  11.0  12.0  12.0         0.0    yes        0.0  12.0
# 22   ...         0.0  12.0  13.0  14.0         0.0     no        2.0  15.0
# 23   ...         2.0  10.0  10.0  10.0         0.0     no        0.0  13.0
# 24   ...         2.0  10.0  11.0  10.0         0.0    yes        2.0  10.0
# 25   ...         6.0  10.0  11.0  12.0         2.0    yes       14.0   6.0
# 26   ...         8.0  11.0  12.0  12.0         0.0    yes        2.0  12.0
# 27   ...         0.0  11.0  11.0  11.0         0.0    yes        4.0  15.0
# 28   ...         2.0  12.0  12.0  13.0         0.0     no        4.0  11.0
# 29   ...         4.0  12.0  11.0  12.0         0.0    yes       16.0  10.0
# ..   ...         ...   ...   ...   ...         ...    ...        ...   ...
# 644  ...         4.0  10.0  11.0  10.0         1.0     no        0.0   7.0
# 645  ...         4.0  15.0  15.0  16.0         0.0    yes        0.0   7.0
# 646  ...         6.0  11.0  12.0   9.0         1.0     no        0.0   6.0
# 647  ...         6.0  10.0  10.0  10.0         0.0     no        3.0  14.0
# 648  ...         4.0  10.0  11.0  11.0         0.0     no        0.0  11.0
# 649  ...         NaN   NaN   NaN   NaN         2.0     no        0.0   7.0
# 650  ...         NaN   NaN   NaN   NaN         2.0     no        6.0   5.0
# 651  ...         NaN   NaN   NaN   NaN         1.0     no        0.0   7.0
# 652  ...         NaN   NaN   NaN   NaN         0.0     no        2.0  10.0
# 653  ...         NaN   NaN   NaN   NaN         1.0     no       16.0  12.0
# 654  ...         NaN   NaN   NaN   NaN         1.0     no       12.0  12.0
# 655  ...         NaN   NaN   NaN   NaN         1.0     no       20.0  15.0
# 656  ...         NaN   NaN   NaN   NaN         1.0    yes        8.0  14.0
# 657  ...         NaN   NaN   NaN   NaN         1.0    yes       38.0   8.0
# 658  ...         NaN   NaN   NaN   NaN         1.0     no       18.0  12.0
# 659  ...         NaN   NaN   NaN   NaN         1.0     no        0.0   9.0
# 660  ...         NaN   NaN   NaN   NaN         0.0     no       20.0  14.0
# 661  ...         NaN   NaN   NaN   NaN         1.0     no        3.0  13.0
# 662  ...         NaN   NaN   NaN   NaN         1.0    yes       22.0  13.0
# 663  ...         NaN   NaN   NaN   NaN         2.0     no       14.0  15.0
# 664  ...         NaN   NaN   NaN   NaN         1.0     no       40.0  13.0
# 665  ...         NaN   NaN   NaN   NaN         1.0    yes       12.0  14.0
# 666  ...         NaN   NaN   NaN   NaN         1.0    yes        4.0  11.0
# 667  ...         NaN   NaN   NaN   NaN         0.0     no        0.0  13.0
# 668  ...         NaN   NaN   NaN   NaN         1.0     no        2.0  13.0
# 669  ...         NaN   NaN   NaN   NaN         2.0     no        4.0   7.0
# 670  ...         NaN   NaN   NaN   NaN         2.0    yes        4.0  15.0
# 671  ...         NaN   NaN   NaN   NaN         2.0    yes       11.0   9.0
# 672  ...         NaN   NaN   NaN   NaN         3.0     no        3.0  10.0
# 673  ...         NaN   NaN   NaN   NaN         0.0     no        5.0   8.0
#
#      G2_y  G3_y
# 0     6.0   6.0
# 1     5.0   6.0
# 2     8.0  10.0
# 3    14.0  15.0
# 4    10.0  10.0
# 5    15.0  15.0
# 6    12.0  11.0
# 7     5.0   6.0
# 8    18.0  19.0
# 9    15.0  15.0
# 10    8.0   9.0
# 11   12.0  12.0
# 12   14.0  14.0
# 13   10.0  11.0
# 14   16.0  16.0
# 15   14.0  14.0
# 16   14.0  14.0
# 17   10.0  10.0
# 18    5.0   5.0
# 19   10.0  10.0
# 20   14.0  15.0
# 21   15.0  15.0
# 22   15.0  16.0
# 23   13.0  12.0
# 24    9.0   8.0
# 25    9.0   8.0
# 26   12.0  11.0
# 27   16.0  15.0
# 28   11.0  11.0
# 29   12.0  11.0
# ..    ...   ...
# 644   5.0   0.0
# 645   9.0   8.0
# 646   5.0   0.0
# 647  16.0  16.0
# 648  12.0  10.0
# 649   4.0   0.0
# 650   9.0   7.0
# 651   0.0   0.0
# 652  10.0  10.0
# 653  11.0  12.0
# 654  12.0  13.0
# 655  14.0  13.0
# 656  12.0  12.0
# 657   9.0   8.0
# 658  10.0  10.0
# 659   9.0   0.0
# 660  12.0  13.0
# 661  11.0  11.0
# 662  10.0  11.0
# 663  13.0  13.0
# 664  11.0  11.0
# 665  13.0  13.0
# 666  12.0  11.0
# 667  13.0  13.0
# 668  12.0  12.0
# 669   7.0   9.0
# 670  14.0  15.0
# 671   9.0   9.0
# 672   8.0   7.0
# 673   9.0   9.0
#
# [674 rows x 39 columns]

# %%
student.shape
# Out:
# (674, 39)

# %%
student.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 674 entries, 0 to 673
# Data columns (total 39 columns):
# school        674 non-null object
# sex           674 non-null object
# age           674 non-null int64
# address       674 non-null object
# famsize       674 non-null object
# Pstatus       674 non-null object
# Medu          674 non-null int64
# Fedu          674 non-null int64
# Mjob          674 non-null object
# Fjob          674 non-null object
# reason        674 non-null object
# guardian      674 non-null object
# traveltime    674 non-null int64
# studytime     674 non-null int64
# failures_x    649 non-null float64
# schoolsup     674 non-null object
# famsup        674 non-null object
# paid_x        649 non-null object
# activities    674 non-null object
# nursery       674 non-null object
# higher        674 non-null object
# internet      674 non-null object
# romantic      674 non-null object
# famrel        674 non-null int64
# freetime      674 non-null int64
# goout         674 non-null int64
# Dalc          674 non-null int64
# Walc          674 non-null int64
# health        674 non-null int64
# absences_x    649 non-null float64
# G1_x          649 non-null float64
# G2_x          649 non-null float64
# G3_x          649 non-null float64
# failures_y    395 non-null float64
# paid_y        395 non-null object
# absences_y    395 non-null float64
# G1_y          395 non-null float64
# G2_y          395 non-null float64
# G3_y          395 non-null float64
# dtypes: float64(10), int64(11), object(18)
# memory usage: 210.6+ KB

# %%
student.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime  failures_x  \
# count  674.000000  674.000000  674.000000  674.000000  674.000000  649.000000
# mean    16.808605    2.495549    2.295252    1.565282    1.930267    0.221880
# std      1.264623    1.133370    1.097237    0.745096    0.824695    0.593235
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000
# G2_y         -0.180003  0.538202  0.578045  0.515173   -0.355896   -0.031777
# G3_y         -0.172685  0.511910  0.551052  0.493134   -0.360415    0.034247
#
#                 G1_y      G2_y      G3_y
# age        -0.064081 -0.143474 -0.161579
# Medu        0.205341  0.215527  0.217147
# Fedu        0.190270  0.164893  0.152457
# traveltime -0.093040 -0.153198 -0.117142
# studytime   0.160612  0.135880  0.097820
# failures_x -0.121907 -0.107459 -0.105387
# famrel      0.022168 -0.018281  0.051363
# freetime    0.012613 -0.013777  0.011307
# goout      -0.149104 -0.162250 -0.132791
# Dalc       -0.094159 -0.064120 -0.054660
# Walc       -0.126179 -0.084927 -0.051939
# health     -0.073172 -0.097720 -0.061335
# absences_x -0.150299 -0.180003 -0.172685
# G1_x        0.581019  0.538202  0.511910
# G2_x        0.598267  0.578045  0.551052
# G3_x        0.559518  0.515173  0.493134
# failures_y -0.354718 -0.355896 -0.360415
# absences_y -0.031003 -0.031777  0.034247
# G1_y        1.000000  0.852118  0.801468
# G2_y        0.852118  1.000000  0.904868
# G3_y        0.801468  0.904868  1.000000
#
# [21 rows x 21 columns]

# %%
student.corr()

f,ax=plt.subplots(figsize=(18,18))
sns.heatmap(student.corr(),annot=True,linewidth=0.5,fmt='.3f',ax=ax)
plt.show()

# %% [markdown]
# In the correlation map, we can see that there is a high positive association fathers education level and mothers education level Also, there is a very high positive correlation between the grades of the students and there is moderate positive relation between workdays and weekend alcohol consumption. And we can say that going out and weekend alcohol consumption have moderate positive correlation.

# %% [markdown]
# # Alcohol consumption level

# %%
l=[1,2,3,4,5]
labels="1-Very Low","2-Low","3-Medium","4-High","5-Very High"

# %% [markdown]
# # AGE

# %% [markdown]
# In the first descriptive statistical table, we found that ages ranged from 15 to 22 years. Now let's see what these ages are.

# %%
student.age.unique()
# Out:
# array([18, 17, 15, 16, 19, 22, 20, 21], dtype=int64)

# %% [markdown]
# Students ages are 15, 16, 17, 18, 19, 20, 21, 22. Also you can also see age percentage in the chart below.

# %%
student.age.unique()
plt.figure(figsize=(10,5))
plt.hist(student.age,bins=7,color="blue",width=0.8,density=True)
plt.xlabel("Age")
plt.ylabel("Percentage")
plt.show()

# %% [markdown]
# # SEX

# %%
female=student[student.sex=="F"]
male= student[student.sex=="M"]

# %%
female.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime  failures_x  \
# count  396.000000  396.000000  396.000000  396.000000  396.000000  383.000000
# mean    16.856061    2.391414    2.219697    1.542929    2.083333    0.185379
# std      1.216756    1.120952    1.081357    0.715595    0.795955    0.516325
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    1.000000    1.000000    1.000000    2.000000    0.000000
# 50%     17.000000    2.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    3.000000    3.000000    2.000000    3.000000    0.000000
# max     21.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc     ...          health  \
# count  396.000000  396.000000  396.000000  396.000000     ...      396.000000
# mean     3.871212    3.047980    3.116162    1.277778     ...        3.363636
# std      0.978803    1.023877    1.152495    0.651084     ...        1.468346
# min      1.000000    1.000000    1.000000    1.000000     ...        1.000000
# 25%      3.750000    2.000000    2.000000    1.000000     ...        2.000000
# 50%      4.000000    3.000000    3.000000    1.000000     ...        3.000000
# 75%      4.250000    4.000000    4.000000    1.000000     ...        5.000000
# max      5.000000    5.000000    5.000000    5.000000     ...        5.000000
#
#        absences_x        G1_x        G2_x        G3_x  failures_y  absences_y  \
# count  383.000000  383.000000  383.000000  383.000000  208.000000  208.000000
# mean     3.577023   11.637076   11.822454   12.253264    0.302885    6.216346
# std      4.667891    2.794232    2.967506    3.124147    0.701683    9.445819
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000   10.000000   10.000000   10.000000    0.000000    0.000000
# 50%      2.000000   12.000000   12.000000   12.000000    0.000000    4.000000
# 75%      5.000000   14.000000   14.000000   14.000000    0.000000    8.000000
# max     32.000000   19.000000   19.000000   19.000000    3.000000   75.000000
#
#              G1_y        G2_y        G3_y
# count  208.000000  208.000000  208.000000
# mean    10.620192   10.389423    9.966346
# std      3.232530    3.641851    4.622338
# min      4.000000    0.000000    0.000000
# 25%      8.000000    8.000000    8.000000
# 50%     10.000000   10.000000   10.000000
# 75%     13.000000   13.000000   13.000000
# max     19.000000   18.000000   19.000000
#
# [8 rows x 21 columns]

# %% [markdown]
# There are 396 female students in this dataset and their average alcohol consumption level is 1.27 on working days and 1.93 on weekends.

# %%
female_workday= list(map(lambda l: list(female.Dalc).count(l),l))
female_weekend= list(map(lambda l: list(female.Walc).count(l),l))

n = 5
fig, ax = plt.subplots(figsize=(10,5))
i = np.arange(n)    
w = 0.4   

plot1= plt.bar(i, female_workday, w, color="g")
plot2= plt.bar(i+w, female_weekend, w, color="r" )

plt.ylabel('Number of Student')
plt.title('Female Student Alcohol Consumption')
plt.xticks(i+w/2, labels)
plt.legend((plot1[0],plot2[0]),("Workday","Weekend"))
plt.tight_layout()
plt.style.use("bmh")
plt.show()

# %% [markdown]
# On the working days, female students alcohol consumtion level is generally very low, however on the weekends they consumes more alcohol medium-high level.

# %%
male.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime  failures_x  \
# count  278.000000  278.000000  278.000000  278.000000  278.000000  266.000000
# mean    16.741007    2.643885    2.402878    1.597122    1.712230    0.274436
# std      1.329141    1.136440    1.112576    0.785422    0.817185    0.686710
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc     ...          health  \
# count  278.000000  278.000000  278.000000  278.000000     ...      278.000000
# mean     4.028777    3.388489    3.266187    1.816547     ...        3.773381
# std      0.890726    1.071527    1.180929    1.133099     ...        1.352525
# min      1.000000    1.000000    1.000000    1.000000     ...        1.000000
# 25%      4.000000    3.000000    2.000000    1.000000     ...        3.000000
# 50%      4.000000    3.000000    3.000000    1.000000     ...        4.000000
# 75%      5.000000    4.000000    4.000000    2.000000     ...        5.000000
# max      5.000000    5.000000    5.000000    5.000000     ...        5.000000
#
#        absences_x        G1_x        G2_x        G3_x  failures_y  absences_y  \
# count  266.000000  266.000000  266.000000  266.000000  187.000000  187.000000
# mean     3.778195   11.056391   11.206767   11.406015    0.368984    5.144385
# std      4.607587    2.640865    2.800019    3.320690    0.788152    5.980749
# min      0.000000    4.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    9.000000    9.000000   10.000000    0.000000    0.000000
# 50%      2.000000   11.000000   11.000000   11.000000    0.000000    4.000000
# 75%      6.000000   13.000000   13.000000   13.000000    0.000000    8.000000
# max     26.000000   18.000000   18.000000   19.000000    3.000000   38.000000
#
#              G1_y        G2_y        G3_y
# count  187.000000  187.000000  187.000000
# mean    11.229947   11.074866   10.914439
# std      3.392839    3.868088    4.495297
# min      3.000000    0.000000    0.000000
# 25%      9.000000    9.000000    9.000000
# 50%     11.000000   11.000000   11.000000
# 75%     14.000000   14.000000   14.000000
# max     19.000000   19.000000   20.000000
#
# [8 rows x 21 columns]

# %% [markdown]
# There are 278 male students in this dataset and their average alcohol consumption level is 1.81 on working days and 2.77 on weekends.

# %%
male_workday= list(map(lambda l: list(male.Dalc).count(l),l))
male_weekend= list(map(lambda l: list(male.Walc).count(l),l))

n = 5
fig, ax = plt.subplots(figsize=(10,5))
i = np.arange(n)    
w = 0.4   

plot1= plt.bar(i, male_workday, w, color="cadetblue")
plot2= plt.bar(i+w,male_weekend, w, color="b" )

plt.ylabel("Number of Student")
plt.title("Male Student Alcohol Consumption")
plt.xticks(i+w/2, labels)
plt.legend((plot1[0],plot2[0]),("Workday","Weekend"))
plt.tight_layout()
plt.style.use("bmh")
plt.show()

# %% [markdown]
# Looking at the figures, when we compare the alcohol consumption level of male and female students, we see that male students consume much more alcohol. And also level of alcohol consumption of male students is much higher than the compared to other specifications on other working days and especially on weekends.

# %% [markdown]
# # SCHOOL

# %%
student.school.unique()
# Out:
# array(['GP', 'MS'], dtype=object)

# %% [markdown]
# There are 2 types of school in this dataset. GP represents Gabriel Pereira and MS is Mousinho da Silveira

# %%
GP=student[student.school=="GP"]
MS= student[student.school=="MS"]

# %%
GP.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime  failures_x  \
# count  441.000000  441.000000  441.000000  441.000000  441.000000  423.000000
# mean    16.727891    2.698413    2.458050    1.428571    2.011338    0.172577
# std      1.280400    1.079656    1.094899    0.700649    0.835224    0.551607
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc     ...          health  \
# count  441.000000  441.000000  441.000000  441.000000     ...      441.000000
# mean     3.956916    3.160998    3.138322    1.458050     ...        3.582766
# std      0.879284    0.994952    1.144713    0.886097     ...        1.410375
# min      1.000000    1.000000    1.000000    1.000000     ...        1.000000
# 25%      4.000000    3.000000    2.000000    1.000000     ...        3.000000
# 50%      4.000000    3.000000    3.000000    1.000000     ...        4.000000
# 75%      5.000000    4.000000    4.000000    2.000000     ...        5.000000
# max      5.000000    5.000000    5.000000    5.000000     ...        5.000000
#
#        absences_x        G1_x        G2_x        G3_x  failures_y  absences_y  \
# count  423.000000  423.000000  423.000000  423.000000  349.000000  349.000000
# mean     4.215130   11.985816   12.144208   12.576832    0.318052    5.965616
# std      5.191915    2.418293    2.451522    2.625636    0.734409    8.341764
# min      0.000000    0.000000    6.000000    0.000000    0.000000    0.000000
# 25%      0.000000   10.000000   10.000000   11.000000    0.000000    0.000000
# 50%      2.000000   12.000000   12.000000   13.000000    0.000000    4.000000
# 75%      6.000000   14.000000   14.000000   14.000000    0.000000    8.000000
# max     32.000000   18.000000   19.000000   19.000000    3.000000   75.000000
#
#              G1_y        G2_y        G3_y
# count  349.000000  349.000000  349.000000
# mean    10.939828   10.782235   10.489971
# std      3.319109    3.808434    4.625397
# min      3.000000    0.000000    0.000000
# 25%      8.000000    9.000000    8.000000
# 50%     11.000000   11.000000   11.000000
# 75%     13.000000   13.000000   14.000000
# max     19.000000   19.000000   20.000000
#
# [8 rows x 21 columns]

# %% [markdown]
# There are 441 students in the Gabriel Pereira School. Their alcohol consumption level is 1.45 on working days and 2.25 on weekends.

# %%
GP_workday= list(map(lambda l: list(GP.Dalc).count(l),l))

colors="mediumspringgreen","orchid","orangered","darkgoldenrod","aqua"
plt.figure(figsize=(8,8))
plt.pie(GP_workday,colors=colors,autopct='%1.1f%%', startangle=90)
plt.title("GP Students Workday Alcohol Consumptions")
plt.legend(labels)
plt.show()

# %% [markdown]
# 71.4% of the GP students consume alcohol in the very low level, 18.6% low level, 5% medium level and 2.7% high and 2.3% very high levels on the working days.

# %%
GP_weekend= list(map(lambda l: list(GP.Walc).count(l),l))

plt.figure(figsize=(8,8))
plt.pie(GP_weekend,colors=colors,autopct='%1.1f%%', startangle=90)
plt.title("GP Students Weekend Alcohol Consumptions")
plt.legend(labels)
plt.show()

# %% [markdown]
# However, weekends alcohol consumption level percentage is changing according to workdays. 40% percentage of GP students consume alcohol in the very low level, 21.8% low level, 17.9% medium level, 13.6% high level and 6.8 very high level.

# %%
MS.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime  failures_x  \
# count  233.000000  233.000000  233.000000  233.000000  233.000000  226.000000
# mean    16.961373    2.111588    1.987124    1.824034    1.776824    0.314159
# std      1.222371    1.135438    1.035910    0.759382    0.783435    0.655556
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    1.000000    1.000000    1.000000    1.000000    0.000000
# 50%     17.000000    2.000000    2.000000    2.000000    2.000000    0.000000
# 75%     18.000000    3.000000    3.000000    2.000000    2.000000    0.000000
# max     21.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc    ...          health  \
# count  233.000000  233.000000  233.000000  233.000000    ...      233.000000
# mean     3.896996    3.240343    3.253219    1.579399    ...        3.437768
# std      1.061732    1.164379    1.203551    0.979930    ...        1.478798
# min      1.000000    1.000000    1.000000    1.000000    ...        1.000000
# 25%      4.000000    3.000000    2.000000    1.000000    ...        2.000000
# 50%      4.000000    3.000000    3.000000    1.000000    ...        4.000000
# 75%      5.000000    4.000000    4.000000    2.000000    ...        5.000000
# max      5.000000    5.000000    5.000000    5.000000    ...        5.000000
#
#        absences_x        G1_x        G2_x        G3_x  failures_y  absences_y  \
# count  226.000000  226.000000  226.000000  226.000000   46.000000   46.000000
# mean     2.619469   10.300885   10.495575   10.650442    0.456522    3.760870
# std      3.130690    2.979590    3.376057    3.833991    0.808470    4.274913
# min      0.000000    4.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    8.000000    9.000000    9.000000    0.000000    0.000000
# 50%      2.000000   10.000000   10.000000   11.000000    0.000000    3.000000
# 75%      4.000000   12.000000   12.750000   13.000000    1.000000    4.750000
# max     12.000000   19.000000   18.000000   19.000000    3.000000   17.000000
#
#             G1_y       G2_y       G3_y
# count  46.000000  46.000000  46.000000
# mean   10.673913  10.195652   9.847826
# std     3.347001   3.377175   4.237229
# min     6.000000   5.000000   0.000000
# 25%     8.000000   8.000000   8.000000
# 50%    10.500000  10.000000  10.000000
# 75%    13.000000  12.750000  12.750000
# max    19.000000  18.000000  19.000000
#
# [8 rows x 21 columns]

# %% [markdown]
# There are 233 students in the Mousinho da Silveira School. Their average alcohol consumption level is 1.57 on working days and 2.33 on weekends.

# %%
MS_workday= list(map(lambda l: list(MS.Dalc).count(l),l))
colors2="sandybrown","springgreen","tomato","grey","pink"
plt.figure(figsize=(8,8))
plt.pie(MS_workday,colors=colors2,autopct='%1.1f%%', startangle=90)
plt.title("MS Students Workday Alcohol Consumptions")
plt.legend(labels)
plt.show()

# %% [markdown]
# 66.1% of the MS students consume alcohol in the very low level, 18.5% low level, 10% medium level and 2.6% high and 3% very high levels on the working days. It seems MS students are consuming more alcohol than GP students on the working days.

# %%
MS_weekend= list(map(lambda l: list(MS.Walc).count(l),l))
plt.figure(figsize=(8,8))
plt.pie(MS_weekend,colors=colors2,autopct='%1.1f%%', startangle=90)
plt.title("MS Students Weekend Alcohol Consumptions")
plt.legend(labels)
plt.show()

# %% [markdown]
# 34.8% percentage of MS students consume alcohol in the very low level, 25.3% low level, 19.7% medium level, 13.3% high level and 6.9 very high level on weekends. Although MS students consume more alcohol than GP students on working days, this rate slightly descrease during the weekend

# %% [markdown]
# # ADDRESS

# %%
student.address.unique()
# Out:
# array(['U', 'R'], dtype=object)

# %% [markdown]
# There are two different student types by address. U represents urban, R is rural.

# %%
urban=student[student.address=="U"]
rural= student[student.address=="R"]

# %%
urban.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime  failures_x  \
# count  470.000000  470.000000  470.000000  470.000000  470.000000  452.000000
# mean    16.793617    2.634043    2.393617    1.400000    1.961702    0.196903
# std      1.260335    1.118802    1.092893    0.634475    0.814724    0.567946
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc     ...          health  \
# count  470.000000  470.000000  470.000000  470.000000     ...      470.000000
# mean     3.914894    3.163830    3.187234    1.472340     ...        3.527660
# std      0.955955    1.022544    1.156721    0.910892     ...        1.443418
# min      1.000000    1.000000    1.000000    1.000000     ...        1.000000
# 25%      4.000000    3.000000    2.000000    1.000000     ...        2.000000
# 50%      4.000000    3.000000    3.000000    1.000000     ...        4.000000
# 75%      5.000000    4.000000    4.000000    2.000000     ...        5.000000
# max      5.000000    5.000000    5.000000    5.000000     ...        5.000000
#
#        absences_x        G1_x        G2_x        G3_x  failures_y  absences_y  \
# count  452.000000  452.000000  452.000000  452.000000  307.000000  307.000000
# mean     3.884956   11.683628   11.867257   12.263274    0.302932    5.589577
# std      4.903960    2.708187    2.779413    2.987658    0.720447    7.506051
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000   10.000000   10.000000   10.000000    0.000000    0.000000
# 50%      2.000000   12.000000   12.000000   12.000000    0.000000    4.000000
# 75%      6.000000   14.000000   14.000000   14.000000    0.000000    8.000000
# max     32.000000   19.000000   18.000000   19.000000    3.000000   56.000000
#
#              G1_y        G2_y        G3_y
# count  307.000000  307.000000  307.000000
# mean    11.032573   10.967427   10.674267
# std      3.285776    3.690508    4.563075
# min      4.000000    0.000000    0.000000
# 25%      8.000000    9.000000    9.000000
# 50%     11.000000   11.000000   11.000000
# 75%     14.000000   14.000000   14.000000
# max     19.000000   19.000000   20.000000
#
# [8 rows x 21 columns]

# %% [markdown]
# There are 470 students living in urban area. Their average alcohol consumption level is 1.47 on working days and 2.26 on weekends.

# %%
urban_workday=list(map(lambda l: list(urban.Dalc).count(l),l))
urban_weekend=list(map(lambda l: list(urban.Walc).count(l),l))

n = 5
fig, ax = plt.subplots(figsize=(10,5))
i = np.arange(n)   
w = 0.4   

plot1= plt.bar(i, urban_workday, w, color="peachpuff")
plot2= plt.bar(i+w, urban_weekend, w, color="skyblue" )

plt.ylabel('Number of Student')
plt.title('Urban Student Alcohol Consumption')
plt.xticks(i+w/2, labels)
plt.legend((plot1[0],plot2[0]),("Workday","Weekend"))
plt.tight_layout()
plt.grid()
plt.show()

# %%
rural.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime  failures_x  \
# count  204.000000  204.000000  204.000000  204.000000  204.000000  197.000000
# mean    16.843137    2.176471    2.068627    1.946078    1.857843    0.279188
# std      1.276889    1.104507    1.076024    0.837563    0.844797    0.645410
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    1.000000    1.000000    1.000000    1.000000    0.000000
# 50%     17.000000    2.000000    2.000000    2.000000    2.000000    0.000000
# 75%     18.000000    3.000000    3.000000    2.000000    2.000000    0.000000
# max     21.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc    ...          health  \
# count  204.000000  204.000000  204.000000  204.000000    ...      204.000000
# mean     3.985294    3.245098    3.156863    1.563725    ...        3.544118
# std      0.923038    1.131164    1.188990    0.942096    ...        1.418740
# min      1.000000    1.000000    1.000000    1.000000    ...        1.000000
# 25%      4.000000    3.000000    2.000000    1.000000    ...        2.000000
# 50%      4.000000    3.000000    3.000000    1.000000    ...        4.000000
# 75%      5.000000    4.000000    4.000000    2.000000    ...        5.000000
# max      5.000000    5.000000    5.000000    5.000000    ...        5.000000
#
#        absences_x        G1_x        G2_x        G3_x  failures_y  absences_y  \
# count  197.000000  197.000000  197.000000  197.000000   88.000000   88.000000
# mean     3.142132   10.746193   10.888325   11.086294    0.443182    6.125000
# std      3.934424    2.724894    3.101632    3.605221    0.814494    9.574646
# min      0.000000    4.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    9.000000    9.000000   10.000000    0.000000    1.000000
# 50%      2.000000   10.000000   11.000000   11.000000    0.000000    4.000000
# 75%      4.000000   13.000000   13.000000   13.000000    1.000000    8.000000
# max     21.000000   18.000000   19.000000   19.000000    3.000000   75.000000
#
#             G1_y       G2_y       G3_y
# count  88.000000  88.000000  88.000000
# mean   10.477273   9.829545   9.511364
# std     3.417256   3.892881   4.556149
# min     3.000000   0.000000   0.000000
# 25%     8.000000   8.000000   7.000000
# 50%    10.000000  10.000000  10.000000
# 75%    13.000000  12.000000  12.000000
# max    19.000000  18.000000  19.000000
#
# [8 rows x 21 columns]

# %% [markdown]
# There are 204 students living in rural area. Their average alcohol consumption level is 1.56 on working days and 2.31 on weekends.

# %%
rural_workday=list(map(lambda l: list(rural.Dalc).count(l),l))
rural_weekend=list(map(lambda l: list(rural.Walc).count(l),l))

n = 5
fig, ax = plt.subplots(figsize=(10,5))
i = np.arange(n)    
w = 0.4 
p1= plt.bar(i, rural_workday, w, color="lightsalmon")
p2= plt.bar(i+w,rural_weekend, w, color="cornflowerblue" )

plt.ylabel('Number of Student')
plt.title('Rural Student Alcohol Consumption')
plt.xticks(i+w/2, labels)
plt.legend((p1[0],p2[0]),("Workday","Weekend"))
plt.tight_layout()
plt.grid()
plt.show()

# %% [markdown]
# According to the graphs, students living in urban areas consume more alcohol than students living in rural areas

# %% [markdown]
# # CONCLUSION

# %% [markdown]
# When we consider the average alcohol consumption levels of all students, we see that all of the features we examined are very close to the average levels of alcohol consumption. In the df table below, features are shown according to their number and average working day and weekenend alcohol consumption levels(from 1 - very low to 5 - very high).

# %%
d= {"Feature": ["All Students","Female","Male","GP","MS","Urban","Rural"],
    "Count": [student.shape[0],female.shape[0],male.shape[0],GP.shape[0],MS.shape[0],urban.shape[0],rural.shape[0]],
    "Average Working Day Alcohol Consumption": [student.Dalc.mean(),female.Dalc.mean(),male.Dalc.mean(),GP.Dalc.mean(),
                                                MS.Dalc.mean(),urban.Dalc.mean(),rural.Dalc.mean()],
    "Average Weekend Alcohol Consumption": [student.Walc.mean(),female.Walc.mean(),male.Walc.mean(),GP.Walc.mean(),
                                            MS.Walc.mean(),urban.Walc.mean(),rural.Walc.mean()]}

df=pd.DataFrame(d)

# %%
df
# Out:
#         Feature  Count  Average Working Day Alcohol Consumption  \
# 0  All Students    674                                 1.500000
# 1        Female    396                                 1.277778
# 2          Male    278                                 1.816547
# 3            GP    441                                 1.458050
# 4            MS    233                                 1.579399
# 5         Urban    470                                 1.472340
# 6         Rural    204                                 1.563725
#
#    Average Weekend Alcohol Consumption
# 0                             2.278932
# 1                             1.931818
# 2                             2.773381
# 3                             2.256236
# 4                             2.321888
# 5                             2.261702
# 6                             2.318627

# %%
df[['Average Working Day Alcohol Consumption','Average Weekend Alcohol Consumption']].plot()

# %%
df1 = pd.read_csv("student-mat.csv")
df2 = pd.read_csv("student-por.csv")
result = df1.append(df2)
result = result.reset_index(drop=True)
result
# Out:
#      school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0        GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1        GP   F   17       U     GT3       T     1     1   at_home     other
# 2        GP   F   15       U     LE3       T     1     1   at_home     other
# 3        GP   F   15       U     GT3       T     4     2    health  services
# 4        GP   F   16       U     GT3       T     3     3     other     other
# 5        GP   M   16       U     LE3       T     4     3  services     other
# 6        GP   M   16       U     LE3       T     2     2     other     other
# 7        GP   F   17       U     GT3       A     4     4     other   teacher
# 8        GP   M   15       U     LE3       A     3     2  services     other
# 9        GP   M   15       U     GT3       T     3     4     other     other
# 10       GP   F   15       U     GT3       T     4     4   teacher    health
# 11       GP   F   15       U     GT3       T     2     1  services     other
# 12       GP   M   15       U     LE3       T     4     4    health  services
# 13       GP   M   15       U     GT3       T     4     3   teacher     other
# 14       GP   M   15       U     GT3       A     2     2     other     other
# 15       GP   F   16       U     GT3       T     4     4    health     other
# 16       GP   F   16       U     GT3       T     4     4  services  services
# 17       GP   F   16       U     GT3       T     3     3     other     other
# 18       GP   M   17       U     GT3       T     3     2  services  services
# 19       GP   M   16       U     LE3       T     4     3    health     other
# 20       GP   M   15       U     GT3       T     4     3   teacher     other
# 21       GP   M   15       U     GT3       T     4     4    health    health
# 22       GP   M   16       U     LE3       T     4     2   teacher     other
# 23       GP   M   16       U     LE3       T     2     2     other     other
# 24       GP   F   15       R     GT3       T     2     4  services    health
# 25       GP   F   16       U     GT3       T     2     2  services  services
# 26       GP   M   15       U     GT3       T     2     2     other     other
# 27       GP   M   15       U     GT3       T     4     2    health  services
# 28       GP   M   16       U     LE3       A     3     4  services     other
# 29       GP   M   16       U     GT3       T     4     4   teacher   teacher
# ...     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 1014     MS   F   18       U     GT3       T     3     3  services  services
# 1015     MS   F   17       U     LE3       T     4     4   at_home   at_home
# 1016     MS   F   17       R     GT3       T     1     2     other  services
# 1017     MS   M   18       R     GT3       T     1     3   at_home     other
# 1018     MS   M   18       U     LE3       T     4     4   teacher  services
# 1019     MS   F   17       R     GT3       T     1     1     other  services
# 1020     MS   F   18       U     GT3       T     2     3   at_home  services
# 1021     MS   F   18       R     GT3       T     4     4     other   teacher
# 1022     MS   M   18       R     LE3       T     1     2   at_home  services
# 1023     MS   F   17       U     GT3       T     2     2     other   at_home
# 1024     MS   F   17       R     GT3       T     1     2     other     other
# 1025     MS   F   18       R     LE3       T     4     4     other     other
# 1026     MS   F   18       R     GT3       T     1     1     other     other
# 1027     MS   F   19       R     GT3       T     1     1   at_home     other
# 1028     MS   F   18       R     LE3       T     4     4   teacher  services
# 1029     MS   F   18       U     GT3       T     3     3     other     other
# 1030     MS   F   17       R     GT3       T     3     1   at_home     other
# 1031     MS   M   18       U     GT3       T     4     4   teacher   teacher
#
...      4        4      1     3     4      5        4  10  11  11
#
# [1044 rows x 33 columns]

# %%
#Normalize absences value
fabs = result[["absences"]].values
fabs = np.where(fabs > 10, 1, 0)
fabs
# Out:
# array([[0],
#        [0],
#        [0],
#        ...,
#        [0],
#        [0],
#        [0]])

# %%
#Represent Alcohol Consumption in One Week
target = ((result[["Walc"]].values * 2) + (result[["Dalc"]].values * 5)/7)
target = np.where(target >= 3, 1, 0)
target
# Out:
# array([[0],
#        [0],
#        [1],
#        ...,
#        [0],
#        [1],
#        [1]])

# %%
res = pd.DataFrame(fabs)
res.columns = ['fabs']

# %%
res2 = pd.DataFrame(target)
res2.columns = ['target']

# %%
fix = result.join(res, how='outer')
fix2 = fix.join(res2, how='outer')
fix2.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1  at_home     other
# 2     GP   F   15       U     LE3       T     1     1  at_home     other
# 3     GP   F   15       U     GT3       T     4     2   health  services
# 4     GP   F   16       U     GT3       T     3     3    other     other
#
#    ...   goout Dalc  Walc  health  absences  G1  G2  G3 fabs target
# 0  ...       4    1     1       3         6   5   6   6    0      0
# 1  ...       3    1     1       3         4   5   5   6    0      0
# 2  ...       2    2     3       3        10   7   8  10    0      1
# 3  ...       2    1     1       5         2  15  14  15    0      0
# 4  ...       2    1     2       5         4   6  10  10    0      1
#
# [5 rows x 35 columns]

# %%
del fix2['Walc']
del fix2['Dalc']
del fix2['absences']

# %%
fix2.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1  at_home     other
# 2     GP   F   15       U     LE3       T     1     1  at_home     other
# 3     GP   F   15       U     GT3       T     4     2   health  services
# 4     GP   F   16       U     GT3       T     3     3    other     other
#
#    ...   romantic famrel  freetime  goout  health  G1  G2  G3 fabs target
# 0  ...         no      4         3      4       3   5   6   6    0      0
# 1  ...         no      5         3      3       3   5   5   6    0      0
# 2  ...         no      4         3      2       3   7   8  10    0      1
# 3  ...        yes      3         2      2       5  15  14  15    0      0
# 4  ...         no      4         3      2       5   6  10  10    0      1
#
# [5 rows x 32 columns]

# %%
fix2.shape
# Out:
# (1044, 32)

# %%
fix2 = fix2.reindex(np.random.permutation(fix2.index))
X = fix2[fix2.columns[0:31]]
Y = fix2['target'].astype('category')

# %%
olist = list(X.select_dtypes(['object']))
for col in olist:
    X[col] = X[col].astype('category').cat.codes
# Out:
# C:\Users\Naveen\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.20, random_state=42)

# %%
from sklearn import tree
from sklearn import metrics
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)
clf.score(X_train, y_train)
# Out:
# 1.0

# %%
y_pred = clf.predict(X_test)
acc_test = metrics.accuracy_score(y_test,y_pred)
acc_test
# Out:
# 0.7751196172248804

# %%
from sklearn.ensemble import RandomForestClassifier
forest = RandomForestClassifier(n_estimators = 100)
forest = forest.fit(X_train, y_train)
forest.score(X_train, y_train)
y_pred = forest.predict(X_test)
acc_test = metrics.accuracy_score(y_test,y_pred)
acc_test
# Out:
# 0.8086124401913876

# %%
importances = pd.DataFrame({'feature':X_train.columns,'importance':np.round(forest.feature_importances_,3)})
importances = importances.sort_values('importance',ascending=False).set_index('feature')
print (importances)
importances.plot.bar()
# Out:
#             importance
# feature
# goout            0.072
# age              0.059
# G3               0.057
# G1               0.057
# health           0.054
# G2               0.054
# studytime        0.052
# famrel           0.045
# Fedu             0.044
# freetime         0.042
# Medu             0.042
# Mjob             0.042
# Fjob             0.042
# sex              0.035
# reason           0.032
# traveltime       0.026
# guardian         0.024
# activities       0.022
# schoolsup        0.022
# famsup           0.019
# famsize          0.019
# romantic         0.019
# nursery          0.018
# address          0.016
# internet         0.015
# school           0.014
# Pstatus          0.014
# paid             0.013
# failures         0.013
# fabs             0.009
# higher           0.006
